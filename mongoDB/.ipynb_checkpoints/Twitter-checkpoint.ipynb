# %% [markdown]
# # Twitter y MongoDB

# %% [markdown]
# De las múltiples librerías que nos permiten usar la API de Twitter, usaremos [Python Twitter Tools](https://github.com/sixohsix/twitter). Con esta librería podremos descargar tweets e información de sus usuarios, así que el **ejercicio** será modelar estas dos entidades y almacenar instancias de ellas.
#
# La idea de este ejercicio está basada en uno anterior que realizó [Gabriel Muñoz](https://twitter.com/Gabi_mu_ri).

# %% [markdown]
# ## Requisitos

# %% [markdown]
# * Python:
#   * `jupyter`
#   * [`twitter`](https://github.com/sixohsix/twitter)
#   * `pymongo`
#   * `mongoengine`
# * MongoDB

# %% [markdown]
# ## El modelo

# %% [markdown]
# Más o menos todos tenemos en la cabeza como funciona Twitter:
# * Un usuario puede publicar cero o muchos tweets.
# * Un tweet tienes varias propiedades, siendo una de ellas el tweet en si, donde podemos encontrar:
#   * Texto.
#   * Menciones a otros usuarios: [`@josemazo`](https://twitter.com/josemazo).
#   * Enlaces: [`https://www.mongodb.org/`](https://www.mongodb.org/).
#   * Hashtags: `#MongoDB`.

# %% [markdown]
# ## Autorización

# %% [markdown]
# Para usar la API pública de Twitter necesitamos ciertos parámetros, así que vamos a ver como obtenerlos.
# 1. Debemos tener una cuenta en Twitter y estar logueados.
# 2. Visitamos [https://apps.twitter.com/](https://apps.twitter.com/) y pulsamos sobre **`Create New App`**.
# ![Pasos 1 y 2](https://i.imgur.com/85p8ROC.png)
# 3. Rellenamos los campos obligatorios:
#   * **`Name`**: debe ser único.
#   * **`Description`**: debe tener más de 10 carácteres.
#   * **`Website`**: debe ser una URL válida.
#   * **`Yes, I agree`**: debemos marcar ese checkbox.
#   * Finalmente puslamos sobre **`Create your Twitter application`**.
# ![Paso 3](https://i.imgur.com/Yi3vATT.png)
# 4. Pulsamos en el enlace **`Keys and Access Tokens`**.
# ![Paso 4](https://i.imgur.com/BVbSK4M.png)
# 5. En `Application Settings` tenemos dos de los parámetros que necesitamos:
#   * **`Consumer Key`**
#   * **`Consumer Secret`**
# ![Paso 5](https://i.imgur.com/R0UQFTq.png)
# 6. Al final de la misma página hay un botón que dice **`Create my access token`**, pulsamos sobre él.
# ![Paso 6](https://i.imgur.com/x6HO5Wy.png)
# 7. De nuevo al final de esa misma página, bajo `Your Access Token` tenemos los otros dos parámetros restantes:
#   * **`Access Token`**
#   * **`Access Token Secret`**
# ![Paso 7](https://i.imgur.com/oNvj1z5.png)

# %% [markdown]
# ## ¡A programar!

# %%
# Importing packages
from bson.objectid import ObjectId
import datetime
from mongoengine import *
import twitter

# %%
# Twitter configuration, we need to use the parameters that we got before
CONSUMER_KEY = ''
CONSUMER_SECRET = ''
ACCESS_TOKEN = ''
ACCESS_TOKEN_SECRET = ''

auth = twitter.oauth.OAuth(ACCESS_TOKEN, ACCESS_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# %%
# MongoDB configuration
connect('twitter', host='localhost', port=27017)
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, read_preference=Primary())

# %% [markdown]
# Vamos a obtener tweets, para ellos usaremos la API y veremos que nos devuelve.

# %%
# Obtaining tweets
search_word = '#goya2017'  # We can search by a word, a text or a hashtag
count = 200

search_results = twitter_api.search.tweets(q=search_word, count=count, lang='es')
search_results
# Out:
# {'search_metadata': {'completed_in': 0.118,
#   'count': 100,
#   'max_id': 828304366885076997,
#   'max_id_str': '828304366885076997',
#   'next_results': '?max_id=828303440543612927&q=%23goya2017&lang=es&count=100&include_entities=1',
#   'query': '%23goya2017',
#   'refresh_url': '?since_id=828304366885076997&q=%23goya2017&lang=es&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Feb 05 18:08:44 +0000 2017',
#    'entities': {'hashtags': [{'indices': [30, 39], 'text': 'Goya2017'}],
#     'media': [{'display_url': 'pic.twitter.com/Zxcl9EAMvJ',
#       'expanded_url': 'https://twitter.com/Aquel_Coche/status/828000811263393793/photo/1',
#       'id': 828000805970182145,
#       'id_str': '828000805970182145',
#       'indices': [40, 63],
#       'media_url': 'http://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#       'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 599},
#        'medium': {'h': 399, 'resize': 'fit', 'w': 599},
#        'small': {'h': 399, 'resize': 'fit', 'w': 599},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 828000811263393793,
#       'source_status_id_str': '828000811263393793',
#       'source_user_id': 3380960747,
#       'source_user_id_str': '3380960747',
#       'type': 'photo',
#       'url': 'https://t.co/Zxcl9EAMvJ'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3380960747,
#       'id_str': '3380960747',
#       'indices': [3, 15],
#       'name': 'S_Coche',
#       'screen_name': 'Aquel_Coche'}]},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/Zxcl9EAMvJ',
#       'expanded_url': 'https://twitter.com/Aquel_Coche/status/828000811263393793/photo/1',
#       'id': 828000805970182145,
#       'id_str': '828000805970182145',
#       'indices': [40, 63],
#       'media_url': 'http://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#       'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 599},
#        'medium': {'h': 399, 'resize': 'fit', 'w': 599},
#        'small': {'h': 399, 'resize': 'fit', 'w': 599},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 828000811263393793,
#       'source_status_id_str': '828000811263393793',
#       'source_user_id': 3380960747,
#       'source_user_id_str': '3380960747',
#       'type': 'photo',
#       'url': 'https://t.co/Zxcl9EAMvJ'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 828304366885076997,
#    'id_str': '828304366885076997',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 582,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Feb 04 22:02:31 +0000 2017',
#     'entities': {'hashtags': [{'indices': [13, 22], 'text': 'Goya2017'}],
#      'media': [{'display_url': 'pic.twitter.com/Zxcl9EAMvJ',
#        'expanded_url': 'https://twitter.com/Aquel_Coche/status/828000811263393793/photo/1',
#        'id': 828000805970182145,
#        'id_str': '828000805970182145',
#        'indices': [23, 46],
#        'media_url': 'http://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#        'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 599},
#         'medium': {'h': 399, 'resize': 'fit', 'w': 599},
#         'small': {'h': 399, 'resize': 'fit', 'w': 599},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/Zxcl9EAMvJ'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'extended_entities': {'media': [{'display_url': 'pic.twitter.com/Zxcl9EAMvJ',
#        'expanded_url': 'https://twitter.com/Aquel_Coche/status/828000811263393793/photo/1',
#        'id': 828000805970182145,
#        'id_str': '828000805970182145',
#        'indices': [23, 46],
#        'media_url': 'http://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#        'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 599},
#         'medium': {'h': 399, 'resize': 'fit', 'w': 599},
#         'small': {'h': 399, 'resize': 'fit', 'w': 599},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/Zxcl9EAMvJ'}]},
#     'favorite_count': 617,
#     'favorited': False,
#     'geo': None,
#     'id': 828000811263393793,
#     'id_str': '828000811263393793',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 582,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'Mejor corto.\n#Goya2017 https://t.co/Zxcl9EAMvJ',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Jul 17 22:30:41 +0000 2015',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'La mayoría de mis seguidores son taxistas.\n COMPENDIO DE PARIDAS, AQUÍ:\nhttps://t.co/HcsFGrNrEh',
#      'entities': {'description': {'urls': [{'display_url': 'twitter.com/Aquel_Coche/st…',
#          'expanded_url': 'https://twitter.com/Aquel_Coche/status/775401318722797568',
#          'indices': [72, 95],
#          'url': 'https://t.co/HcsFGrNrEh'}]},
#       'url': {'urls': [{'display_url': 'es.favstar.fm/users/Aquel_Co…',
#          'expanded_url': 'http://es.favstar.fm/users/Aquel_Coche',
#          'indices': [0, 23],
#          'url': 'https://t.co/E3fWGijh5l'}]}},
#      'favourites_count': 12219,
#      'follow_request_sent': False,
#      'followers_count': 2730,
#      'following': False,
#      'friends_count': 495,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 3380960747,
#      'id_str': '3380960747',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 42,
#      'location': 'On the road',
#      'name': 'S_Coche',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3380960747/1447257246',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/818937243373109248/ZbTnVVih_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/818937243373109248/ZbTnVVih_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'Aquel_Coche',
#      'statuses_count': 16740,
#      'time_zone': 'Lisbon',
#      'translator_type': 'none',
#      'url': 'https://t.co/E3fWGijh5l',
#      'utc_offset': 0,
#      'verified': False}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @Aquel_Coche: Mejor corto.\n#Goya2017 https://t.co/Zxcl9EAMvJ',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Feb 08 17:33:26 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 1660,
#     'follow_request_sent': False,
#     'followers_count': 208,
#     'following': False,
#     'friends_count': 915,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 4889145250,
#     'id_str': '4889145250',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 11,
#     'location': '',
#     'name': 'buenprovecho',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4889145250/1454953180',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/696749674661867520/qu2HwUKz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/696749674661867520/qu2HwUKz_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': '_buenprovecho_',
#     'statuses_count': 6787,
#     'time_zone': 'Central America',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -21600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Feb 05 18:08:38 +0000 2017',
#    'entities': {'hashtags': [{'indices': [54, 63], 'text': 'goya2017'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 11904592,
#       'id_str': '11904592',
#       'indices': [3, 11],
#       'name': 'Alberto Garzón',
#       'screen_name': 'agarzon'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 828304340314157071,
#    'id_str': '828304340314157071',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 958,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Feb 04 23:00:43 +0000 2017',
#     'entities': {'hashtags': [{'indices': [41, 50], 'text': 'goya2017'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 2347,
#     'favorited': False,
#     'geo': None,
#     'id': 828015458909560832,
#     'id_str': '828015458909560832',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 958,
#     'retweeted': False,
#     'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>',
#     'text': 'Gran momento de Silvia Perez Cruz en los #goya2017 con su canción reivindicativa ‘No hay tanto pan’. Directo al corazón y muy necesaria.',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sun Jan 06 12:37:43 +0000 2008',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': "Economista, Coordinador Federal de @iunida Activista y defensor de los derechos humanos. Autor de 'A pie de escaño' (Península, 2015)",
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'agarzon.net',
#          'expanded_url': 'http://www.agarzon.net',
#          'indices': [0, 23],
#          'url': 'https://t.co/OX9uPldrCP'}]}},
#      'favourites_count': 182,
#      'follow_request_sent': False,
#      'followers_count': 720307,
#      'following': False,
#      'friends_count': 1162,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 11904592,
#      'id_str': '11904592',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 5969,
#      'location': 'Málaga',
#      'name': 'Alberto Garzón',
#      'notifications': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/11904592/1484160945',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/760028030479831040/743PYZds_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/760028030479831040/743PYZds_normal.jpg',
#      'profile_link_color': '009999',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'agarzon',
#      'statuses_count': 49860,
#      'time_zone': 'Madrid',
#      'translator_type': 'none',
#      'url': 'https://t.co/OX9uPldrCP',
#      'utc_offset': 3600,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @agarzon: Gran momento de Silvia Perez Cruz en los #goya2017 con su canción reivindicativa ‘No hay tanto pan’. Directo al corazón y muy…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Jul 31 09:14:35 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'El viejo mundo se muere. El nuevo tarda en aparecer. Y en ese claroscuro surgen los monstruos.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'blogdehistoriaderafa.wordpress.com',
#         'expanded_url': 'https://blogdehistoriaderafa.wordpress.com/',
#         'indices': [0, 23],
#         'url': 'https://t.co/KrpTWHmSi4'}]}},
#     'favourites_count': 2402,
#     'follow_request_sent': False,
#     'followers_count': 567,
#     'following': False,
#     'friends_count': 1177,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 727980019,
#     'id_str': '727980019',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 15,
#     'location': 'Andalucía & Yorkshire',
#     'name': 'Rafael Linde Ruiz',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/727980019/1456417728',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/702891664856236032/Qc_p5Q5Q_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/702891664856236032/Qc_p5Q5Q_normal.jpg',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'RafaelLindeRuiz',
#     'statuses_count': 17782,
#     'time_zone': 'Amsterdam',
#     'translator_type': 'none',
#     'url': 'https://t.co/KrpTWHmSi4',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Feb 05 18:08:37 +0000 2017',
#    'entities': {'hashtags': [{'indices': [102, 111], 'text': 'Goya2017'}],
#     'media': [{'display_url': 'pic.twitter.com/oh3phR7BGR',
#       'expanded_url': 'https://twitter.com/rtve/status/828003008063565824/video/1',
#       'id': 828002902811631616,
#       'id_str': '828002902811631616',
#       'indices': [112, 135],
#       'media_url': 'http://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#        'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 828003008063565824,
#       'source_status_id_str': '828003008063565824',
#       'source_user_id': 26729931,
#       'source_user_id_str': '26729931',
#       'type': 'photo',
#       'url': 'https://t.co/oh3phR7BGR'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 136666412,
#       'id_str': '136666412',
#       'indices': [3, 18],
#       'name': 'juan carlos mohr',
#       'screen_name': 'juancarlosmohr'}]},
#    'extended_entities': {'media': [{'additional_media_info': {'description': 'Powered by SnappyTV',
#        'embeddable': True,
#        'monetizable': False,
#        'source_user': {'contributors_enabled': False,
#         'created_at': 'Thu Mar 26 11:41:06 +0000 2009',
#         'default_profile': False,
#         'default_profile_image': False,
#         'description': 'Canal oficial en Twitter de RTVE, Radio Televisión Española. La actualidad, desde la radiotelevisión pública.',
#         'entities': {'description': {'urls': []},
#          'url': {'urls': [{'display_url': 'rtve.es',
#             'expanded_url': 'http://www.rtve.es',
#             'indices': [0, 22],
#             'url': 'http://t.co/KTjbdNhmQr'}]}},
#         'favourites_count': 772,
#         'follow_request_sent': False,
#         'followers_count': 1018425,
#         'following': False,
#         'friends_count': 332,
#         'geo_enabled': True,
#         'has_extended_profile': False,
#         'id': 26729931,
#         'id_str': '26729931',
#         'is_translation_enabled': False,
#         'is_translator': False,
#         'lang': 'es',
#         'listed_count': 12565,
#         'location': 'Madrid, España',
#         'name': 'RTVE',
#         'notifications': False,
#         'profile_background_color': 'EF841A',
#         'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/206099486/rtvetwitter.jpg',
#         'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/206099486/rtvetwitter.jpg',
#         'profile_background_tile': False,
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26729931/1472053387',
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/449524195529981952/6uemF5nU_normal.jpeg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/449524195529981952/6uemF5nU_normal.jpeg',
#         'profile_link_color': '0084B4',
#         'profile_sidebar_border_color': 'FFFFFF',
#         'profile_sidebar_fill_color': 'E8511F',
#         'profile_text_color': '333333',
#         'profile_use_background_image': False,
#         'protected': False,
#         'screen_name': 'rtve',
#         'statuses_count': 133191,
#         'time_zone': 'Madrid',
#         'translator_type': 'none',
#         'url': 'http://t.co/KTjbdNhmQr',
#         'utc_offset': 3600,
#         'verified': True},
#        'title': 'Video'},
#       'display_url': 'pic.twitter.com/oh3phR7BGR',
#       'expanded_url': 'https://twitter.com/rtve/status/828003008063565824/video/1',
#       'id': 828002902811631616,
#       'id_str': '828002902811631616',
#       'indices': [112, 135],
#       'media_url': 'http://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#        'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 828003008063565824,
#       'source_status_id_str': '828003008063565824',
#       'source_user_id': 26729931,
#       'source_user_id_str': '26729931',
#       'type': 'video',
#       'url': 'https://t.co/oh3phR7BGR',
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 74560,
#        'variants': [{'content_type': 'application/dash+xml',
#          'url': 'https://video.twimg.com/amplify_video/828002902811631616/pl/mFKKbRJ4LJvX0Gyt.mpd'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/amplify_video/828002902811631616/pl/mFKKbRJ4LJvX0Gyt.m3u8'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/828002902811631616/vid/640x360/Fl6x3VjG6_bNpDTa.mp4'},
#         {'bitrate': 320000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/828002902811631616/vid/320x180/JcHKeytlYxqNeDR3.mp4'}]}}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 828304336811864066,
#    'id_str': '828304336811864066',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 2399,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Feb 04 22:16:58 +0000 2017',
#     'entities': {'hashtags': [{'indices': [82, 91], 'text': 'Goya2017'}],
#      'media': [{'display_url': 'pic.twitter.com/oh3phR7BGR',
#        'expanded_url': 'https://twitter.com/rtve/status/828003008063565824/video/1',
#        'id': 828002902811631616,
#        'id_str': '828002902811631616',
#        'indices': [92, 115],
#        'media_url': 'http://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#        'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#         'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#         'small': {'h': 383, 'resize': 'fit', 'w': 680},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'source_status_id': 828003008063565824,
#        'source_status_id_str': '828003008063565824',
#        'source_user_id': 26729931,
#        'source_user_id_str': '26729931',
#        'type': 'photo',
#        'url': 'https://t.co/oh3phR7BGR'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'extended_entities': {'media': [{'additional_media_info': {'description': 'Powered by SnappyTV',
#         'embeddable': True,
#         'monetizable': False,
#         'source_user': {'contributors_enabled': False,
#          'created_at': 'Thu Mar 26 11:41:06 +0000 2009',
#          'default_profile': False,
#          'default_profile_image': False,
#          'description': 'Canal oficial en Twitter de RTVE, Radio Televisión Española. La actualidad, desde la radiotelevisión pública.',
#          'entities': {'description': {'urls': []},
#           'url': {'urls': [{'display_url': 'rtve.es',
#              'expanded_url': 'http://www.rtve.es',
#              'indices': [0, 22],
#              'url': 'http://t.co/KTjbdNhmQr'}]}},
#          'favourites_count': 772,
#          'follow_request_sent': False,
#          'followers_count': 1018425,
#          'following': False,
#          'friends_count': 332,
#          'geo_enabled': True,
#          'has_extended_profile': False,
#          'id': 26729931,
#          'id_str': '26729931',
#          'is_translation_enabled': False,
#          'is_translator': False,
#          'lang': 'es',
#          'listed_count': 12565,
#          'location': 'Madrid, España',
#          'name': 'RTVE',
#          'notifications': False,
#          'profile_background_color': 'EF841A',
#          'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/206099486/rtvetwitter.jpg',
#          'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/206099486/rtvetwitter.jpg',
#          'profile_background_tile': False,
#          'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26729931/1472053387',
#          'profile_image_url': 'http://pbs.twimg.com/profile_images/449524195529981952/6uemF5nU_normal.jpeg',
#          'profile_image_url_https': 'https://pbs.twimg.com/profile_images/449524195529981952/6uemF5nU_normal.jpeg',
#          'profile_link_color': '0084B4',
#          'profile_sidebar_border_color': 'FFFFFF',
#          'profile_sidebar_fill_color': 'E8511F',
#          'profile_text_color': '333333',
#          'profile_use_background_image': False,
#          'protected': False,
#          'screen_name': 'rtve',
#          'statuses_count': 133191,
#          'time_zone': 'Madrid',
#          'translator_type': 'none',
#          'url': 'http://t.co/KTjbdNhmQr',
#          'utc_offset': 3600,
#          'verified': True},
#         'title': 'Video'},
#        'display_url': 'pic.twitter.com/oh3phR7BGR',
#        'expanded_url': 'https://twitter.com/rtve/status/828003008063565824/video/1',
#        'id': 828002902811631616,
#        'id_str': '828002902811631616',
#        'indices': [92, 115],
#        'media_url': 'http://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#        'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#         'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#         'small': {'h': 383, 'resize': 'fit', 'w': 680},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'source_status_id': 828003008063565824,
#        'source_status_id_str': '828003008063565824',
#        'source_user_id': 26729931,
#        'source_user_id_str': '26729931',
#        'type': 'video',
#        'url': 'https://t.co/oh3phR7BGR',
#        'video_info': {'aspect_ratio': [16, 9],
#         'duration_millis': 74560,
#         'variants': [{'content_type': 'application/dash+xml',
#           'url': 'https://video.twimg.com/amplify_video/828002902811631616/pl/mFKKbRJ4LJvX0Gyt.mpd'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/amplify_video/828002902811631616/pl/mFKKbRJ4LJvX0Gyt.m3u8'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/828002902811631616/vid/640x360/Fl6x3VjG6_bNpDTa.mp4'},
#          {'bitrate': 320000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/828002902811631616/vid/320x180/JcHKeytlYxqNeDR3.mp4'}]}}]},
#     'favorite_count': 2370,
#     'favorited': False,
#     'geo': None,
#     'id': 828004447842365451,
#     'id_str': '828004447842365451',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 2399,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Grande Silvia Pérez Cruz cantando "es indecente gente sin casas, casas sin gente" #Goya2017 https://t.co/oh3phR7BGR',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sat Apr 24 15:24:05 +0000 2010',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Ser profesional no es tener un titulo. Ser profesional es saber lo que estas haciendo. https://t.co/tA6uJGELjx https://t.co/D5W1oeYsun',
#      'entities': {'description': {'urls': [{'display_url': 'youtube.com/user/tiojon44',
#          'expanded_url': 'http://www.youtube.com/user/tiojon44',
#          'indices': [87, 110],
#          'url': 'https://t.co/tA6uJGELjx'},
#         {'display_url': 'Instagram.com/juancarlosmohr',
#          'expanded_url': 'http://Instagram.com/juancarlosmohr',
#          'indices': [111, 134],
#          'url': 'https://t.co/D5W1oeYsun'}]},
#       'url': {'urls': [{'display_url': 'youtube.com/user/tiojon44',
#          'expanded_url': 'http://www.youtube.com/user/tiojon44',
#          'indices': [0, 23],
#          'url': 'https://t.co/tA6uJGELjx'}]}},
#      'favourites_count': 9740,
#      'follow_request_sent': False,
#      'followers_count': 19452,
#      'following': False,
#      'friends_count': 1020,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 136666412,
#      'id_str': '136666412',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 386,
#      'location': '',
#      'name': 'juan carlos mohr',
#      'notifications': False,
#      'profile_background_color': 'ABB8C2',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/136666412/1477244340',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/678888090329575429/ua1Mj29w_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/678888090329575429/ua1Mj29w_normal.jpg',
#      'profile_link_color': '3B4F70',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DFEFF0',
#      'profile_text_color': '383138',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'juancarlosmohr',
#      'statuses_count': 54264,
#      'time_zone': 'Greenland',
#      'translator_type': 'none',
#      'url': 'https://t.co/tA6uJGELjx',
#      'utc_offset': -10800,
#      'verified': False}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @juancarlosmohr: Grande Silvia Pérez Cruz cantando "es indecente gente sin casas, casas sin gente" #Goya2017 https://t.co/oh3phR7BGR',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Jan 10 17:05:33 +0000 2013',
#     'default_profile': True,
#     'default_profile_image': True,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 14,
#     'follow_request_sent': False,
#     'followers_count': 7,
#     'following': False,
#     'friends_count': 11,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1077138919,
#     'id_str': '1077138919',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 0,
#     'location': '',
#     'name': 'Albert Burgos',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_3_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_3_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'albert_fburgos',
#     'statuses_count': 9,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Feb 05 18:08:35 +0000 2017',
#    'entities': {'hashtags': [{'indices': [16, 21], 'text': 'Cine'},
#      {'indices': [28, 47], 'text': 'elciudadanoilustre'},
#      {'indices': [48, 57], 'text': 'goya2017'}],
#     'symbols': [],
#     'urls': [{'display_url': 'anajosefasilva.cl/comedia/ciudad…',
#       'expanded_url': 'http://anajosefasilva.cl/comedia/ciudadano-ilustre-una-acida-comedia-cuentas-pendientes/',
#       'indices': [117, 140],
#       'url': 'https://t.co/cFe87oCIXl'}],
#     'user_mentions': [{'id': 50429897,
#       'id_str': '50429897',
#       'indices': [3, 14],
#       'name': 'anajosefasilva.cl',
#       'screen_name': 'ana_josefa'},
#      {'id': 60657564,
#       'id_str': '60657564',
#       'indices': [77, 91],
#       'name': 'Cine Normandie',
#       'screen_name': 'cinenormandie'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 828304326154153988,
#    'id_str': '828304326154153988',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 6,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sun Feb 05 15:07:19 +0000 2017',
#     'entities': {'hashtags': [{'indices': [0, 5], 'text': 'Cine'},
#       {'indices': [12, 31], 'text': 'elciudadanoilustre'},
#       {'indices': [32, 41], 'text': 'goya2017'}],
#      'symbols': [],
#      'urls': [{'display_url': 'anajosefasilva.cl/comedia/ciudad…',
#        'expanded_url': 'http://anajosefasilva.cl/comedia/ciudadano-ilustre-una-acida-comedia-cuentas-pendientes/',
#        'indices': [101, 124],
#        'url': 'https://t.co/cFe87oCIXl'}],
#      'user_mentions': [{'id': 60657564,
#        'id_str': '60657564',
#        'indices': [61, 75],
#        'name': 'Cine Normandie',
#        'screen_name': 'cinenormandie'}]},
#     'favorite_count': 6,
#     'favorited': False,
#     'geo': None,
#     'id': 828258708283064321,
#     'id_str': '828258708283064321',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 6,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': '#Cine Ojo 👇🏻#elciudadanoilustre #goya2017 En Cartelera en el @cinenormandie ¡Se las mega recomiendo! https://t.co/cFe87oCIXl',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jun 24 20:42:48 +0000 2009',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Periodista UC. Crítica de cine. Presidenta Círculo de Críticos de Arte de Chile. Yogui de lunes a sábado. 4 bellos hijos. Casada y feliz.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'anajosefasilva.cl',
#          'expanded_url': 'http://www.anajosefasilva.cl',
#          'indices': [0, 22],
#          'url': 'http://t.co/9Y39q8SQ6A'}]}},
#      'favourites_count': 19276,
#      'follow_request_sent': False,
#      'followers_count': 58083,
#      'following': False,
#      'friends_count': 3126,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 50429897,
#      'id_str': '50429897',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 426,
#      'location': 'Santiago de Chile',
#      'name': 'anajosefasilva.cl',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50429897/1420474407',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/552111703538692097/LCMEJbzM_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/552111703538692097/LCMEJbzM_normal.png',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'ana_josefa',
#      'statuses_count': 73166,
#      'time_zone': 'Santiago',
#      'translator_type': 'none',
#      'url': 'http://t.co/9Y39q8SQ6A',
#      'utc_offset': -10800,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @ana_josefa: #Cine Ojo 👇🏻#elciudadanoilustre #goya2017 En Cartelera en el @cinenormandie ¡Se las mega recomiendo! https://t.co/cFe87oCIXl',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jul 03 23:35:54 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'RRPP @CinemarkChile|Asesora Prensa Distribuidoras|Esposa @octaviofierro|Mamá 🍼|Periodista y Diplomada en Guión|BookLover|Blogger en @BlogDeAnizu https://t.co/mTYIKqrEzB',
#     'entities': {'description': {'urls': [{'display_url': 'anizu.cl',
#         'expanded_url': 'http://www.anizu.cl',
#         'indices': [145, 168],
#         'url': 'https://t.co/mTYIKqrEzB'}]},
#      'url': {'urls': [{'display_url': 'anitazuniga.cl',
#         'expanded_url': 'http://www.anitazuniga.cl',
#         'indices': [0, 23],
#         'url': 'https://t.co/fxWk9H0YwS'}]}},
#     'favourites_count': 19840,
#     'follow_request_sent': False,
#     'followers_count': 6382,
#     'following': False,
#     'friends_count': 384,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 53533566,
#     'id_str': '53533566',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 136,
#     'location': 'Santiago, Chile',
#     'name': '\uf8ff Anita Zúñiga',
#     'notifications': False,
#     'profile_background_color': 'FF6699',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/432289518020878336/d4Xc6Nok.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/432289518020878336/d4Xc6Nok.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/53533566/1397849208',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/657372651351093248/IP6uVx8f_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/657372651351093248/IP6uVx8f_normal.jpg',
#     'profile_link_color': 'B30D65',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'E34FA3',
#     'profile_text_color': '362720',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'AnitaZuniga',
#     'statuses_count': 99367,
#     'time_zone': 'Santiago',
#     'translator_type': 'regular',
#     'url': 'https://t.co/fxWk9H0YwS',
#     'utc_offset': -10800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Feb 05 18:08:27 +0000 2017',
#    'entities': {'hashtags': [{'indices': [64, 73], 'text': 'Goya2017'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/828304295800012801',
#       'indices': [110, 133],
#       'url': 'https://t.co/nnueRilhkA'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 828304295800012801,
#    'id_str': '828304295800012801',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Ana Belén, Emma Suárez, Bayona... La crónica de una gala de los #Goya2017 que encumbró a 'Tarde para la ira'… https://t.co/nnueRilhkA",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Mar 24 19:08:26 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Periodismo a pesar de todo. Colabora: Hazte socio -- http://t.co/CZxxz87oU5',
#     'entities': {'description': {'urls': [{'display_url': 'eldiario.es/socios/alta.ht…',
#         'expanded_url': 'http://www.eldiario.es/socios/alta.html',
#         'indices': [53, 75],
#         'url': 'http://t.co/CZxxz87oU5'}]},
#      'url': {'urls': [{'display_url': 'eldiario.es',
#         'expanded_url': 'http://www.eldiario.es',
#         'indices': [0, 22],
#         'url': 'http://t.co/9SEeSxM6L5'}]}},
#     'favourites_count': 195,
#     'follow_request_sent': False,
#     'followers_count': 647885,
#     'following': False,
#     'friends_count': 447,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 535707261,
#     'id_str': '535707261',
#     'is_translation_enabled': True,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 9683,
#     'location': '',
#     'name': 'eldiario.es',
#     'notifications': False,
#     'profile_background_color': '196CAE',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/520083139431903232/eoV9-_dl.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/520083139431903232/eoV9-_dl.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/535707261/1483547801',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/617606944807886848/C4qa2z6K_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/617606944807886848/C4qa2z6K_normal.png',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'eldiarioes',
#     'statuses_count': 99964,
#     'time_zone': 'Madrid',
#     'translator_type': 'none',
#     'url': 'http://t.co/9SEeSxM6L5',
#     'utc_offset': 3600,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Feb 05 18:08:26 +0000 2017',
#    'entities': {'hashtags': [{'indices': [65, 74], 'text': 'goya2017'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 68740712,
#       'id_str': '68740712',
#       'indices': [3, 19],
#       'name': 'Pedro Sánchez',
#       'screen_name': 'sanchezcastejon'},
#      {'id': 230118325,
#       'id_str': '230118325',
#       'indices': [47, 58],
#       'name': 'JA Bayona',
#       'screen_name': 'FilmBayona'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 828304291660173316,
#    'id_str': '828304291660173316',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 362,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Feb 04 22:59:34 +0000 2017',
#     'entities': {'hashtags': [{'indices': [44, 53], 'text': 'goya2017'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 230118325,
#        'id_str': '230118325',
#        'indices': [26, 37],
#        'name': 'JA Bayona',
#        'screen_name': 'FilmBayona'}]},
#     'favorite_count': 747,
#     'favorited': False,
#     'geo': None,
#     'id': 828015168638558208,
#     'id_str': '828015168638558208',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 362,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Vale mucho, pero que deje @FilmBayona algún #goya2017 !😉 Todo el apoyo a nuestro excepcional cine español. Estamos orgullosos de vosotros@s',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Aug 25 16:45:56 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Padre. Doctor en Economía. Militante del @PSOE.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'sanchezcastejon.es',
#          'expanded_url': 'http://www.sanchezcastejon.es',
#          'indices': [0, 23],
#          'url': 'https://t.co/MbNfjiBSJ0'}]}},
#      'favourites_count': 2521,
#      'follow_request_sent': False,
#      'followers_count': 494906,
#      'following': False,
#      'friends_count': 5932,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 68740712,
#      'id_str': '68740712',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 3143,
#      'location': '',
#      'name': 'Pedro Sánchez',
#      'notifications': False,
#      'profile_background_color': '94D487',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/68740712/1485699061',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/827129616645111808/eMvXadps_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/827129616645111808/eMvXadps_normal.jpg',
#      'profile_link_color': '94D487',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'sanchezcastejon',
#      'statuses_count': 20257,
#      'time_zone': 'Madrid',
#      'translator_type': 'none',
#      'url': 'https://t.co/MbNfjiBSJ0',
#      'utc_offset': 3600,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @sanchezcastejon: Vale mucho, pero que deje @FilmBayona algún #goya2017 !😉 Todo el apoyo a nuestro excepcional cine español. Estamos org…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Nov 17 18:00:31 +0000 2013',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 504,
#     'follow_request_sent': False,
#     'followers_count': 61,
#     'following': False,
#     'friends_count': 233,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 2199945019,
#     'id_str': '2199945019',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 3,
#     'location': 'Gijón,Asturias',
#     'name': 'Isabel',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000753482221/ae9fb5958486090e85b4c36d9ae9e84b_normal.jpeg',
# ...
#          'indices': [0, 23],
#          'url': 'https://t.co/VOazu7ACyg'}]}},
#      'favourites_count': 103,
#      'follow_request_sent': False,
#      'followers_count': 168022,
#      'following': False,
#      'friends_count': 390,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 240665461,
#      'id_str': '240665461',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 956,
#      'location': '',
#      'name': 'Premios #Goya2017',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/664797017810563072/L4KMl7DA.jpg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/664797017810563072/L4KMl7DA.jpg',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/240665461/1481537557',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/808602330933424128/o9dHjJlV_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/808602330933424128/o9dHjJlV_normal.jpg',
#      'profile_link_color': '101060',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'PremiosGoya',
#      'statuses_count': 3475,
#      'time_zone': 'Greenland',
#      'translator_type': 'none',
#      'url': 'https://t.co/VOazu7ACyg',
#      'utc_offset': -10800,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @PremiosGoya: Pau Costa y Félix Bergés son los ganadores del #Goya2017 a Mejores Efectos Especiales por Un monstruo viene a verme. ¡Y ya…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Dec 09 14:42:58 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Sonsoles Zatarain. Lda. en Derecho. Opositando Justicia.Labor Omnia Vincit.Igualdad y libertad.\r\nCántabra. Senderismo/ la Mar.\r\nSoy de Azuqueca de Henares',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 2564,
#     'follow_request_sent': False,
#     'followers_count': 687,
#     'following': False,
#     'friends_count': 831,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 999426997,
#     'id_str': '999426997',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 26,
#     'location': '',
#     'name': 'Sonsoles Zatarain',
#     'notifications': False,
#     'profile_background_color': 'DD2E44',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000079200427/4c07597d63a4f9800674143e57ad6879.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000079200427/4c07597d63a4f9800674143e57ad6879.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/999426997/1469705012',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/816674470228332544/qHwdhCfv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/816674470228332544/qHwdhCfv_normal.jpg',
#     'profile_link_color': 'DD2E44',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'F6FFD1',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'SonsoZatarain',
#     'statuses_count': 5338,
#     'time_zone': 'Amsterdam',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Feb 05 18:05:07 +0000 2017',
#    'entities': {'hashtags': [{'indices': [16, 25], 'text': 'Goya2017'}],
#     'symbols': [],
#     'urls': [{'display_url': 'rtve.es/noticias/los-g…',
#       'expanded_url': 'http://www.rtve.es/noticias/los-goya/directo/?ext=ggTTR',
#       'indices': [113, 136],
#       'url': 'https://t.co/PLOrygZqR4'}],
#     'user_mentions': [{'id': 57986415,
#       'id_str': '57986415',
#       'indices': [3, 11],
#       'name': 'TVE',
#       'screen_name': 'tve_tve'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 828303454456029184,
#    'id_str': '828303454456029184',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 30,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Feb 04 21:37:27 +0000 2017',
#     'entities': {'hashtags': [{'indices': [3, 12], 'text': 'Goya2017'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#        'expanded_url': 'https://twitter.com/i/web/status/827994501637496833',
#        'indices': [101, 124],
#        'url': 'https://t.co/g5Ma5RvFCR'}],
#      'user_mentions': []},
#     'favorite_count': 76,
#     'favorited': False,
#     'geo': None,
#     'id': 827994501637496833,
#     'id_str': '827994501637496833',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 30,
#     'retweeted': False,
#     'source': '<a href="http://snappytv.com" rel="nofollow">SnappyTV.com</a>',
#     'text': 'El #Goya2017 a la mejor dirección de arte es para Eugenio Caballero por ‘Un monstruo viene a verme’… https://t.co/g5Ma5RvFCR',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sat Jul 18 17:42:20 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'TVE te informa de toda su actualidad al minuto.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'rtve.es/television',
#          'expanded_url': 'http://www.rtve.es/television',
#          'indices': [0, 22],
#          'url': 'http://t.co/KFb1Bw5rSt'}]}},
#      'favourites_count': 162,
#      'follow_request_sent': False,
#      'followers_count': 494916,
#      'following': False,
#      'friends_count': 110,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 57986415,
#      'id_str': '57986415',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 4793,
#      'location': 'Madrid, España',
#      'name': 'TVE',
#      'notifications': False,
#      'profile_background_color': '0072FF',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/280190690/TW_tve.jpg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/280190690/TW_tve.jpg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/57986415/1398329854',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/768466852725030912/f0amQkXU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/768466852725030912/f0amQkXU_normal.jpg',
#      'profile_link_color': '0072FF',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'tve_tve',
#      'statuses_count': 48581,
#      'time_zone': 'Madrid',
#      'translator_type': 'none',
#      'url': 'http://t.co/KFb1Bw5rSt',
#      'utc_offset': 3600,
#      'verified': True}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @tve_tve: El #Goya2017 a la mejor dirección de arte es para Eugenio Caballero por ‘Un monstruo viene a verme’ https://t.co/PLOrygZqR4 ht…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Jan 04 14:13:32 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'BELISARIO DOMINGUEZ 625',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 41,
#     'follow_request_sent': False,
#     'followers_count': 207,
#     'following': False,
#     'friends_count': 389,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 2276172698,
#     'id_str': '2276172698',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 44,
#     'location': 'en centro de jalisco Mexico.',
#     'name': 'HOTEL NAVARRO',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2276172698/1483153653',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/826506882533634050/H3chpr7t_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/826506882533634050/H3chpr7t_normal.jpg',
#     'profile_link_color': 'F5ABB5',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'tayloroterocamp',
#     'statuses_count': 15036,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 0,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Feb 05 18:05:04 +0000 2017',
#    'entities': {'hashtags': [{'indices': [128, 137], 'text': 'goya2017'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1568575706,
#       'id_str': '1568575706',
#       'indices': [3, 17],
#       'name': 'LOSANTOSPOSTS Ⓜ️',
#       'screen_name': 'LosantosPosts'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 828303440543612928,
#    'id_str': '828303440543612928',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 90,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sun Feb 05 14:49:37 +0000 2017',
#     'entities': {'hashtags': [{'indices': [109, 118], 'text': 'goya2017'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 112,
#     'favorited': False,
#     'geo': None,
#     'id': 828254254594981888,
#     'id_str': '828254254594981888',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 90,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Para ser comunista español, hay que ser muy rico. Una Ana Belén, una Carmena, un Wyoming o un Víctor Manuel.\n#goya2017',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Jul 04 16:38:15 +0000 2013',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '99% REFLEXIONES DE LOSANTOS. Federico no tiene Twitter, pero Twitter sí tiene a Federico. La ficción supera a la realidad CM:Agente Doble(CommentaryAccount)',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 12619,
#      'follow_request_sent': False,
#      'followers_count': 33532,
#      'following': False,
#      'friends_count': 93,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 1568575706,
#      'id_str': '1568575706',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 425,
#      'location': 'Imperio Español ',
#      'name': 'LOSANTOSPOSTS Ⓜ️',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1568575706/1478691029',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/726194929240793088/R1bVjoRE_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/726194929240793088/R1bVjoRE_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'LosantosPosts',
#      'statuses_count': 25176,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @LosantosPosts: Para ser comunista español, hay que ser muy rico. Una Ana Belén, una Carmena, un Wyoming o un Víctor Manuel.\n#goya2017',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Apr 19 22:33:08 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Pesimista antropológico pero convencido de que, al final, los malos siempre pierden. | #Deporte y #Montaña #Demócrata #Liberal | De #ElBierzo a #Ronda #España',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 3903,
#     'follow_request_sent': False,
#     'followers_count': 1181,
#     'following': False,
#     'friends_count': 559,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 284756189,
#     'id_str': '284756189',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 48,
#     'location': 'Ronda',
#     'name': 'Nardi Crespo Prada',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/595158033/upha0gqjqeykzl7jshpw.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/595158033/upha0gqjqeykzl7jshpw.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/284756189/1479253640',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/797232390716407808/QtLj6QBR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/797232390716407808/QtLj6QBR_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'D5F4FA',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Nardicrespo',
#     'statuses_count': 19498,
#     'time_zone': 'Madrid',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 3600,
#     'verified': False}}]}

# %%
search_results['statuses']
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Feb 05 18:08:44 +0000 2017',
#   'entities': {'hashtags': [{'indices': [30, 39], 'text': 'Goya2017'}],
#    'media': [{'display_url': 'pic.twitter.com/Zxcl9EAMvJ',
#      'expanded_url': 'https://twitter.com/Aquel_Coche/status/828000811263393793/photo/1',
#      'id': 828000805970182145,
#      'id_str': '828000805970182145',
#      'indices': [40, 63],
#      'media_url': 'http://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#      'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 599},
#       'medium': {'h': 399, 'resize': 'fit', 'w': 599},
#       'small': {'h': 399, 'resize': 'fit', 'w': 599},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 828000811263393793,
#      'source_status_id_str': '828000811263393793',
#      'source_user_id': 3380960747,
#      'source_user_id_str': '3380960747',
#      'type': 'photo',
#      'url': 'https://t.co/Zxcl9EAMvJ'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3380960747,
#      'id_str': '3380960747',
#      'indices': [3, 15],
#      'name': 'S_Coche',
#      'screen_name': 'Aquel_Coche'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/Zxcl9EAMvJ',
#      'expanded_url': 'https://twitter.com/Aquel_Coche/status/828000811263393793/photo/1',
#      'id': 828000805970182145,
#      'id_str': '828000805970182145',
#      'indices': [40, 63],
#      'media_url': 'http://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#      'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 599},
#       'medium': {'h': 399, 'resize': 'fit', 'w': 599},
#       'small': {'h': 399, 'resize': 'fit', 'w': 599},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 828000811263393793,
#      'source_status_id_str': '828000811263393793',
#      'source_user_id': 3380960747,
#      'source_user_id_str': '3380960747',
#      'type': 'photo',
#      'url': 'https://t.co/Zxcl9EAMvJ'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 828304366885076997,
#   'id_str': '828304366885076997',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 582,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Feb 04 22:02:31 +0000 2017',
#    'entities': {'hashtags': [{'indices': [13, 22], 'text': 'Goya2017'}],
#     'media': [{'display_url': 'pic.twitter.com/Zxcl9EAMvJ',
#       'expanded_url': 'https://twitter.com/Aquel_Coche/status/828000811263393793/photo/1',
#       'id': 828000805970182145,
#       'id_str': '828000805970182145',
#       'indices': [23, 46],
#       'media_url': 'http://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#       'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 599},
#        'medium': {'h': 399, 'resize': 'fit', 'w': 599},
#        'small': {'h': 399, 'resize': 'fit', 'w': 599},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/Zxcl9EAMvJ'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/Zxcl9EAMvJ',
#       'expanded_url': 'https://twitter.com/Aquel_Coche/status/828000811263393793/photo/1',
#       'id': 828000805970182145,
#       'id_str': '828000805970182145',
#       'indices': [23, 46],
#       'media_url': 'http://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#       'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 599},
#        'medium': {'h': 399, 'resize': 'fit', 'w': 599},
#        'small': {'h': 399, 'resize': 'fit', 'w': 599},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/Zxcl9EAMvJ'}]},
#    'favorite_count': 617,
#    'favorited': False,
#    'geo': None,
#    'id': 828000811263393793,
#    'id_str': '828000811263393793',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 582,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'Mejor corto.\n#Goya2017 https://t.co/Zxcl9EAMvJ',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jul 17 22:30:41 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'La mayoría de mis seguidores son taxistas.\n COMPENDIO DE PARIDAS, AQUÍ:\nhttps://t.co/HcsFGrNrEh',
#     'entities': {'description': {'urls': [{'display_url': 'twitter.com/Aquel_Coche/st…',
#         'expanded_url': 'https://twitter.com/Aquel_Coche/status/775401318722797568',
#         'indices': [72, 95],
#         'url': 'https://t.co/HcsFGrNrEh'}]},
#      'url': {'urls': [{'display_url': 'es.favstar.fm/users/Aquel_Co…',
#         'expanded_url': 'http://es.favstar.fm/users/Aquel_Coche',
#         'indices': [0, 23],
#         'url': 'https://t.co/E3fWGijh5l'}]}},
#     'favourites_count': 12219,
#     'follow_request_sent': False,
#     'followers_count': 2730,
#     'following': False,
#     'friends_count': 495,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 3380960747,
#     'id_str': '3380960747',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 42,
#     'location': 'On the road',
#     'name': 'S_Coche',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3380960747/1447257246',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/818937243373109248/ZbTnVVih_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/818937243373109248/ZbTnVVih_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Aquel_Coche',
#     'statuses_count': 16740,
#     'time_zone': 'Lisbon',
#     'translator_type': 'none',
#     'url': 'https://t.co/E3fWGijh5l',
#     'utc_offset': 0,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @Aquel_Coche: Mejor corto.\n#Goya2017 https://t.co/Zxcl9EAMvJ',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Feb 08 17:33:26 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1660,
#    'follow_request_sent': False,
#    'followers_count': 208,
#    'following': False,
#    'friends_count': 915,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 4889145250,
#    'id_str': '4889145250',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 11,
#    'location': '',
#    'name': 'buenprovecho',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4889145250/1454953180',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/696749674661867520/qu2HwUKz_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/696749674661867520/qu2HwUKz_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': '_buenprovecho_',
#    'statuses_count': 6787,
#    'time_zone': 'Central America',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -21600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Feb 05 18:08:38 +0000 2017',
#   'entities': {'hashtags': [{'indices': [54, 63], 'text': 'goya2017'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 11904592,
#      'id_str': '11904592',
#      'indices': [3, 11],
#      'name': 'Alberto Garzón',
#      'screen_name': 'agarzon'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 828304340314157071,
#   'id_str': '828304340314157071',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 958,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Feb 04 23:00:43 +0000 2017',
#    'entities': {'hashtags': [{'indices': [41, 50], 'text': 'goya2017'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 2347,
#    'favorited': False,
#    'geo': None,
#    'id': 828015458909560832,
#    'id_str': '828015458909560832',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 958,
#    'retweeted': False,
#    'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>',
#    'text': 'Gran momento de Silvia Perez Cruz en los #goya2017 con su canción reivindicativa ‘No hay tanto pan’. Directo al corazón y muy necesaria.',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Jan 06 12:37:43 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Economista, Coordinador Federal de @iunida Activista y defensor de los derechos humanos. Autor de 'A pie de escaño' (Península, 2015)",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'agarzon.net',
#         'expanded_url': 'http://www.agarzon.net',
#         'indices': [0, 23],
#         'url': 'https://t.co/OX9uPldrCP'}]}},
#     'favourites_count': 182,
#     'follow_request_sent': False,
#     'followers_count': 720307,
#     'following': False,
#     'friends_count': 1162,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 11904592,
#     'id_str': '11904592',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 5969,
#     'location': 'Málaga',
#     'name': 'Alberto Garzón',
#     'notifications': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/11904592/1484160945',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/760028030479831040/743PYZds_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/760028030479831040/743PYZds_normal.jpg',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'agarzon',
#     'statuses_count': 49860,
#     'time_zone': 'Madrid',
#     'translator_type': 'none',
#     'url': 'https://t.co/OX9uPldrCP',
#     'utc_offset': 3600,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @agarzon: Gran momento de Silvia Perez Cruz en los #goya2017 con su canción reivindicativa ‘No hay tanto pan’. Directo al corazón y muy…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Jul 31 09:14:35 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'El viejo mundo se muere. El nuevo tarda en aparecer. Y en ese claroscuro surgen los monstruos.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'blogdehistoriaderafa.wordpress.com',
#        'expanded_url': 'https://blogdehistoriaderafa.wordpress.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/KrpTWHmSi4'}]}},
#    'favourites_count': 2402,
#    'follow_request_sent': False,
#    'followers_count': 567,
#    'following': False,
#    'friends_count': 1177,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 727980019,
#    'id_str': '727980019',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 15,
#    'location': 'Andalucía & Yorkshire',
#    'name': 'Rafael Linde Ruiz',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/727980019/1456417728',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/702891664856236032/Qc_p5Q5Q_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/702891664856236032/Qc_p5Q5Q_normal.jpg',
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'RafaelLindeRuiz',
#    'statuses_count': 17782,
#    'time_zone': 'Amsterdam',
#    'translator_type': 'none',
#    'url': 'https://t.co/KrpTWHmSi4',
#    'utc_offset': 3600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Feb 05 18:08:37 +0000 2017',
#   'entities': {'hashtags': [{'indices': [102, 111], 'text': 'Goya2017'}],
#    'media': [{'display_url': 'pic.twitter.com/oh3phR7BGR',
#      'expanded_url': 'https://twitter.com/rtve/status/828003008063565824/video/1',
#      'id': 828002902811631616,
#      'id_str': '828002902811631616',
#      'indices': [112, 135],
#      'media_url': 'http://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#      'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#       'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 383, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 828003008063565824,
#      'source_status_id_str': '828003008063565824',
#      'source_user_id': 26729931,
#      'source_user_id_str': '26729931',
#      'type': 'photo',
#      'url': 'https://t.co/oh3phR7BGR'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 136666412,
#      'id_str': '136666412',
#      'indices': [3, 18],
#      'name': 'juan carlos mohr',
#      'screen_name': 'juancarlosmohr'}]},
#   'extended_entities': {'media': [{'additional_media_info': {'description': 'Powered by SnappyTV',
#       'embeddable': True,
#       'monetizable': False,
#       'source_user': {'contributors_enabled': False,
#        'created_at': 'Thu Mar 26 11:41:06 +0000 2009',
#        'default_profile': False,
#        'default_profile_image': False,
#        'description': 'Canal oficial en Twitter de RTVE, Radio Televisión Española. La actualidad, desde la radiotelevisión pública.',
#        'entities': {'description': {'urls': []},
#         'url': {'urls': [{'display_url': 'rtve.es',
#            'expanded_url': 'http://www.rtve.es',
#            'indices': [0, 22],
#            'url': 'http://t.co/KTjbdNhmQr'}]}},
#        'favourites_count': 772,
#        'follow_request_sent': False,
#        'followers_count': 1018425,
#        'following': False,
#        'friends_count': 332,
#        'geo_enabled': True,
#        'has_extended_profile': False,
#        'id': 26729931,
#        'id_str': '26729931',
#        'is_translation_enabled': False,
#        'is_translator': False,
#        'lang': 'es',
#        'listed_count': 12565,
#        'location': 'Madrid, España',
#        'name': 'RTVE',
#        'notifications': False,
#        'profile_background_color': 'EF841A',
#        'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/206099486/rtvetwitter.jpg',
#        'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/206099486/rtvetwitter.jpg',
#        'profile_background_tile': False,
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26729931/1472053387',
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/449524195529981952/6uemF5nU_normal.jpeg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/449524195529981952/6uemF5nU_normal.jpeg',
#        'profile_link_color': '0084B4',
#        'profile_sidebar_border_color': 'FFFFFF',
#        'profile_sidebar_fill_color': 'E8511F',
#        'profile_text_color': '333333',
#        'profile_use_background_image': False,
#        'protected': False,
#        'screen_name': 'rtve',
#        'statuses_count': 133191,
#        'time_zone': 'Madrid',
#        'translator_type': 'none',
#        'url': 'http://t.co/KTjbdNhmQr',
#        'utc_offset': 3600,
#        'verified': True},
#       'title': 'Video'},
#      'display_url': 'pic.twitter.com/oh3phR7BGR',
#      'expanded_url': 'https://twitter.com/rtve/status/828003008063565824/video/1',
#      'id': 828002902811631616,
#      'id_str': '828002902811631616',
#      'indices': [112, 135],
#      'media_url': 'http://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#      'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#       'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 383, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 828003008063565824,
#      'source_status_id_str': '828003008063565824',
#      'source_user_id': 26729931,
#      'source_user_id_str': '26729931',
#      'type': 'video',
#      'url': 'https://t.co/oh3phR7BGR',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 74560,
#       'variants': [{'content_type': 'application/dash+xml',
#         'url': 'https://video.twimg.com/amplify_video/828002902811631616/pl/mFKKbRJ4LJvX0Gyt.mpd'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/828002902811631616/pl/mFKKbRJ4LJvX0Gyt.m3u8'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/828002902811631616/vid/640x360/Fl6x3VjG6_bNpDTa.mp4'},
#        {'bitrate': 320000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/828002902811631616/vid/320x180/JcHKeytlYxqNeDR3.mp4'}]}}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 828304336811864066,
#   'id_str': '828304336811864066',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 2399,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Feb 04 22:16:58 +0000 2017',
#    'entities': {'hashtags': [{'indices': [82, 91], 'text': 'Goya2017'}],
#     'media': [{'display_url': 'pic.twitter.com/oh3phR7BGR',
#       'expanded_url': 'https://twitter.com/rtve/status/828003008063565824/video/1',
#       'id': 828002902811631616,
#       'id_str': '828002902811631616',
#       'indices': [92, 115],
#       'media_url': 'http://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#        'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 828003008063565824,
#       'source_status_id_str': '828003008063565824',
#       'source_user_id': 26729931,
#       'source_user_id_str': '26729931',
#       'type': 'photo',
#       'url': 'https://t.co/oh3phR7BGR'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'additional_media_info': {'description': 'Powered by SnappyTV',
#        'embeddable': True,
#        'monetizable': False,
#        'source_user': {'contributors_enabled': False,
#         'created_at': 'Thu Mar 26 11:41:06 +0000 2009',
#         'default_profile': False,
#         'default_profile_image': False,
#         'description': 'Canal oficial en Twitter de RTVE, Radio Televisión Española. La actualidad, desde la radiotelevisión pública.',
#         'entities': {'description': {'urls': []},
#          'url': {'urls': [{'display_url': 'rtve.es',
#             'expanded_url': 'http://www.rtve.es',
#             'indices': [0, 22],
#             'url': 'http://t.co/KTjbdNhmQr'}]}},
#         'favourites_count': 772,
#         'follow_request_sent': False,
#         'followers_count': 1018425,
#         'following': False,
#         'friends_count': 332,
#         'geo_enabled': True,
#         'has_extended_profile': False,
#         'id': 26729931,
#         'id_str': '26729931',
#         'is_translation_enabled': False,
#         'is_translator': False,
#         'lang': 'es',
#         'listed_count': 12565,
#         'location': 'Madrid, España',
#         'name': 'RTVE',
#         'notifications': False,
#         'profile_background_color': 'EF841A',
#         'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/206099486/rtvetwitter.jpg',
#         'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/206099486/rtvetwitter.jpg',
#         'profile_background_tile': False,
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26729931/1472053387',
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/449524195529981952/6uemF5nU_normal.jpeg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/449524195529981952/6uemF5nU_normal.jpeg',
#         'profile_link_color': '0084B4',
#         'profile_sidebar_border_color': 'FFFFFF',
#         'profile_sidebar_fill_color': 'E8511F',
#         'profile_text_color': '333333',
#         'profile_use_background_image': False,
#         'protected': False,
#         'screen_name': 'rtve',
#         'statuses_count': 133191,
#         'time_zone': 'Madrid',
#         'translator_type': 'none',
#         'url': 'http://t.co/KTjbdNhmQr',
#         'utc_offset': 3600,
#         'verified': True},
#        'title': 'Video'},
#       'display_url': 'pic.twitter.com/oh3phR7BGR',
#       'expanded_url': 'https://twitter.com/rtve/status/828003008063565824/video/1',
#       'id': 828002902811631616,
#       'id_str': '828002902811631616',
#       'indices': [92, 115],
#       'media_url': 'http://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C32oV9tUEAABK1C.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#        'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 828003008063565824,
#       'source_status_id_str': '828003008063565824',
#       'source_user_id': 26729931,
#       'source_user_id_str': '26729931',
#       'type': 'video',
#       'url': 'https://t.co/oh3phR7BGR',
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 74560,
#        'variants': [{'content_type': 'application/dash+xml',
#          'url': 'https://video.twimg.com/amplify_video/828002902811631616/pl/mFKKbRJ4LJvX0Gyt.mpd'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/amplify_video/828002902811631616/pl/mFKKbRJ4LJvX0Gyt.m3u8'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/828002902811631616/vid/640x360/Fl6x3VjG6_bNpDTa.mp4'},
#         {'bitrate': 320000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/828002902811631616/vid/320x180/JcHKeytlYxqNeDR3.mp4'}]}}]},
#    'favorite_count': 2370,
#    'favorited': False,
#    'geo': None,
#    'id': 828004447842365451,
#    'id_str': '828004447842365451',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 2399,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Grande Silvia Pérez Cruz cantando "es indecente gente sin casas, casas sin gente" #Goya2017 https://t.co/oh3phR7BGR',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Apr 24 15:24:05 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Ser profesional no es tener un titulo. Ser profesional es saber lo que estas haciendo. https://t.co/tA6uJGELjx https://t.co/D5W1oeYsun',
#     'entities': {'description': {'urls': [{'display_url': 'youtube.com/user/tiojon44',
#         'expanded_url': 'http://www.youtube.com/user/tiojon44',
#         'indices': [87, 110],
#         'url': 'https://t.co/tA6uJGELjx'},
#        {'display_url': 'Instagram.com/juancarlosmohr',
#         'expanded_url': 'http://Instagram.com/juancarlosmohr',
#         'indices': [111, 134],
#         'url': 'https://t.co/D5W1oeYsun'}]},
#      'url': {'urls': [{'display_url': 'youtube.com/user/tiojon44',
#         'expanded_url': 'http://www.youtube.com/user/tiojon44',
#         'indices': [0, 23],
#         'url': 'https://t.co/tA6uJGELjx'}]}},
#     'favourites_count': 9740,
#     'follow_request_sent': False,
#     'followers_count': 19452,
#     'following': False,
#     'friends_count': 1020,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 136666412,
#     'id_str': '136666412',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 386,
#     'location': '',
#     'name': 'juan carlos mohr',
#     'notifications': False,
#     'profile_background_color': 'ABB8C2',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/136666412/1477244340',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/678888090329575429/ua1Mj29w_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/678888090329575429/ua1Mj29w_normal.jpg',
#     'profile_link_color': '3B4F70',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DFEFF0',
#     'profile_text_color': '383138',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'juancarlosmohr',
#     'statuses_count': 54264,
#     'time_zone': 'Greenland',
#     'translator_type': 'none',
#     'url': 'https://t.co/tA6uJGELjx',
#     'utc_offset': -10800,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @juancarlosmohr: Grande Silvia Pérez Cruz cantando "es indecente gente sin casas, casas sin gente" #Goya2017 https://t.co/oh3phR7BGR',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Jan 10 17:05:33 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': True,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 14,
#    'follow_request_sent': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 11,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1077138919,
#    'id_str': '1077138919',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 0,
#    'location': '',
#    'name': 'Albert Burgos',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_3_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_3_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'albert_fburgos',
#    'statuses_count': 9,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Feb 05 18:08:35 +0000 2017',
#   'entities': {'hashtags': [{'indices': [16, 21], 'text': 'Cine'},
#     {'indices': [28, 47], 'text': 'elciudadanoilustre'},
#     {'indices': [48, 57], 'text': 'goya2017'}],
#    'symbols': [],
#    'urls': [{'display_url': 'anajosefasilva.cl/comedia/ciudad…',
#      'expanded_url': 'http://anajosefasilva.cl/comedia/ciudadano-ilustre-una-acida-comedia-cuentas-pendientes/',
#      'indices': [117, 140],
#      'url': 'https://t.co/cFe87oCIXl'}],
#    'user_mentions': [{'id': 50429897,
#      'id_str': '50429897',
#      'indices': [3, 14],
#      'name': 'anajosefasilva.cl',
#      'screen_name': 'ana_josefa'},
#     {'id': 60657564,
#      'id_str': '60657564',
#      'indices': [77, 91],
#      'name': 'Cine Normandie',
#      'screen_name': 'cinenormandie'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 828304326154153988,
#   'id_str': '828304326154153988',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 6,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Feb 05 15:07:19 +0000 2017',
#    'entities': {'hashtags': [{'indices': [0, 5], 'text': 'Cine'},
#      {'indices': [12, 31], 'text': 'elciudadanoilustre'},
#      {'indices': [32, 41], 'text': 'goya2017'}],
#     'symbols': [],
#     'urls': [{'display_url': 'anajosefasilva.cl/comedia/ciudad…',
#       'expanded_url': 'http://anajosefasilva.cl/comedia/ciudadano-ilustre-una-acida-comedia-cuentas-pendientes/',
#       'indices': [101, 124],
#       'url': 'https://t.co/cFe87oCIXl'}],
#     'user_mentions': [{'id': 60657564,
#       'id_str': '60657564',
#       'indices': [61, 75],
#       'name': 'Cine Normandie',
#       'screen_name': 'cinenormandie'}]},
#    'favorite_count': 6,
#    'favorited': False,
#    'geo': None,
#    'id': 828258708283064321,
#    'id_str': '828258708283064321',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 6,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '#Cine Ojo 👇🏻#elciudadanoilustre #goya2017 En Cartelera en el @cinenormandie ¡Se las mega recomiendo! https://t.co/cFe87oCIXl',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jun 24 20:42:48 +0000 2009',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Periodista UC. Crítica de cine. Presidenta Círculo de Críticos de Arte de Chile. Yogui de lunes a sábado. 4 bellos hijos. Casada y feliz.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'anajosefasilva.cl',
#         'expanded_url': 'http://www.anajosefasilva.cl',
#         'indices': [0, 22],
#         'url': 'http://t.co/9Y39q8SQ6A'}]}},
#     'favourites_count': 19276,
#     'follow_request_sent': False,
#     'followers_count': 58083,
#     'following': False,
#     'friends_count': 3126,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 50429897,
#     'id_str': '50429897',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 426,
#     'location': 'Santiago de Chile',
#     'name': 'anajosefasilva.cl',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50429897/1420474407',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/552111703538692097/LCMEJbzM_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/552111703538692097/LCMEJbzM_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'ana_josefa',
#     'statuses_count': 73166,
#     'time_zone': 'Santiago',
#     'translator_type': 'none',
#     'url': 'http://t.co/9Y39q8SQ6A',
#     'utc_offset': -10800,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @ana_josefa: #Cine Ojo 👇🏻#elciudadanoilustre #goya2017 En Cartelera en el @cinenormandie ¡Se las mega recomiendo! https://t.co/cFe87oCIXl',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jul 03 23:35:54 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'RRPP @CinemarkChile|Asesora Prensa Distribuidoras|Esposa @octaviofierro|Mamá 🍼|Periodista y Diplomada en Guión|BookLover|Blogger en @BlogDeAnizu https://t.co/mTYIKqrEzB',
#    'entities': {'description': {'urls': [{'display_url': 'anizu.cl',
#        'expanded_url': 'http://www.anizu.cl',
#        'indices': [145, 168],
#        'url': 'https://t.co/mTYIKqrEzB'}]},
#     'url': {'urls': [{'display_url': 'anitazuniga.cl',
#        'expanded_url': 'http://www.anitazuniga.cl',
#        'indices': [0, 23],
#        'url': 'https://t.co/fxWk9H0YwS'}]}},
#    'favourites_count': 19840,
#    'follow_request_sent': False,
#    'followers_count': 6382,
#    'following': False,
#    'friends_count': 384,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 53533566,
#    'id_str': '53533566',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 136,
#    'location': 'Santiago, Chile',
#    'name': '\uf8ff Anita Zúñiga',
#    'notifications': False,
#    'profile_background_color': 'FF6699',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/432289518020878336/d4Xc6Nok.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/432289518020878336/d4Xc6Nok.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/53533566/1397849208',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/657372651351093248/IP6uVx8f_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/657372651351093248/IP6uVx8f_normal.jpg',
#    'profile_link_color': 'B30D65',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'E34FA3',
#    'profile_text_color': '362720',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'AnitaZuniga',
#    'statuses_count': 99367,
#    'time_zone': 'Santiago',
#    'translator_type': 'regular',
#    'url': 'https://t.co/fxWk9H0YwS',
#    'utc_offset': -10800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Feb 05 18:08:27 +0000 2017',
#   'entities': {'hashtags': [{'indices': [64, 73], 'text': 'Goya2017'}],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#      'expanded_url': 'https://twitter.com/i/web/status/828304295800012801',
#      'indices': [110, 133],
#      'url': 'https://t.co/nnueRilhkA'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 828304295800012801,
#   'id_str': '828304295800012801',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': "Ana Belén, Emma Suárez, Bayona... La crónica de una gala de los #Goya2017 que encumbró a 'Tarde para la ira'… https://t.co/nnueRilhkA",
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Mar 24 19:08:26 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Periodismo a pesar de todo. Colabora: Hazte socio -- http://t.co/CZxxz87oU5',
#    'entities': {'description': {'urls': [{'display_url': 'eldiario.es/socios/alta.ht…',
#        'expanded_url': 'http://www.eldiario.es/socios/alta.html',
#        'indices': [53, 75],
#        'url': 'http://t.co/CZxxz87oU5'}]},
#     'url': {'urls': [{'display_url': 'eldiario.es',
#        'expanded_url': 'http://www.eldiario.es',
#        'indices': [0, 22],
#        'url': 'http://t.co/9SEeSxM6L5'}]}},
#    'favourites_count': 195,
#    'follow_request_sent': False,
#    'followers_count': 647885,
#    'following': False,
#    'friends_count': 447,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 535707261,
#    'id_str': '535707261',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 9683,
#    'location': '',
#    'name': 'eldiario.es',
#    'notifications': False,
#    'profile_background_color': '196CAE',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/520083139431903232/eoV9-_dl.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/520083139431903232/eoV9-_dl.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/535707261/1483547801',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/617606944807886848/C4qa2z6K_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/617606944807886848/C4qa2z6K_normal.png',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'eldiarioes',
#    'statuses_count': 99964,
#    'time_zone': 'Madrid',
#    'translator_type': 'none',
#    'url': 'http://t.co/9SEeSxM6L5',
#    'utc_offset': 3600,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Feb 05 18:08:26 +0000 2017',
#   'entities': {'hashtags': [{'indices': [65, 74], 'text': 'goya2017'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 68740712,
#      'id_str': '68740712',
#      'indices': [3, 19],
#      'name': 'Pedro Sánchez',
#      'screen_name': 'sanchezcastejon'},
#     {'id': 230118325,
#      'id_str': '230118325',
#      'indices': [47, 58],
#      'name': 'JA Bayona',
#      'screen_name': 'FilmBayona'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 828304291660173316,
#   'id_str': '828304291660173316',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 362,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Feb 04 22:59:34 +0000 2017',
#    'entities': {'hashtags': [{'indices': [44, 53], 'text': 'goya2017'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 230118325,
#       'id_str': '230118325',
#       'indices': [26, 37],
#       'name': 'JA Bayona',
#       'screen_name': 'FilmBayona'}]},
#    'favorite_count': 747,
#    'favorited': False,
#    'geo': None,
#    'id': 828015168638558208,
#    'id_str': '828015168638558208',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 362,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Vale mucho, pero que deje @FilmBayona algún #goya2017 !😉 Todo el apoyo a nuestro excepcional cine español. Estamos orgullosos de vosotros@s',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Aug 25 16:45:56 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Padre. Doctor en Economía. Militante del @PSOE.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'sanchezcastejon.es',
#         'expanded_url': 'http://www.sanchezcastejon.es',
#         'indices': [0, 23],
#         'url': 'https://t.co/MbNfjiBSJ0'}]}},
#     'favourites_count': 2521,
#     'follow_request_sent': False,
#     'followers_count': 494906,
#     'following': False,
#     'friends_count': 5932,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 68740712,
#     'id_str': '68740712',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 3143,
#     'location': '',
#     'name': 'Pedro Sánchez',
#     'notifications': False,
#     'profile_background_color': '94D487',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/68740712/1485699061',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/827129616645111808/eMvXadps_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/827129616645111808/eMvXadps_normal.jpg',
#     'profile_link_color': '94D487',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'sanchezcastejon',
#     'statuses_count': 20257,
#     'time_zone': 'Madrid',
#     'translator_type': 'none',
#     'url': 'https://t.co/MbNfjiBSJ0',
#     'utc_offset': 3600,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @sanchezcastejon: Vale mucho, pero que deje @FilmBayona algún #goya2017 !😉 Todo el apoyo a nuestro excepcional cine español. Estamos org…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Nov 17 18:00:31 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 504,
#    'follow_request_sent': False,
#    'followers_count': 61,
#    'following': False,
#    'friends_count': 233,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 2199945019,
#    'id_str': '2199945019',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 3,
#    'location': 'Gijón,Asturias',
#    'name': 'Isabel',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000753482221/ae9fb5958486090e85b4c36d9ae9e84b_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000753482221/ae9fb5958486090e85b4c36d9ae9e84b_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'merengue1284',
#    'statuses_count': 362,
#    'time_zone': 'Madrid',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 3600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Feb 05 18:08:22 +0000 2017',
#   'entities': {'hashtags': [{'indices': [83, 94], 'text': 'EmmaSuárez'},
#     {'indices': [105, 114], 'text': 'Goya2017'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/2lcoYMt',
#      'expanded_url': 'http://bit.ly/2lcoYMt',
#      'indices': [116, 139],
#      'url': 'https://t.co/snUIiWgwSN'}],
#    'user_mentions': [{'id': 33906088,
#      'id_str': '33906088',
#      'indices': [3, 14],
#      'name': 'Vogue España',
#      'screen_name': 'VogueSpain'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 828304273675055105,
#   'id_str': '828304273675055105',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 8,
# ...
#     'created_at': 'Thu Jan 20 13:09:34 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Cuenta de los premios de la Academia de las Artes y las Ciencias Cinematográficas de España @Academiadecine #Goya2017',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'premiosgoya.com',
#         'expanded_url': 'http://premiosgoya.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/VOazu7ACyg'}]}},
#     'favourites_count': 103,
#     'follow_request_sent': False,
#     'followers_count': 168022,
#     'following': False,
#     'friends_count': 390,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 240665461,
#     'id_str': '240665461',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 956,
#     'location': '',
#     'name': 'Premios #Goya2017',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/664797017810563072/L4KMl7DA.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/664797017810563072/L4KMl7DA.jpg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/240665461/1481537557',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/808602330933424128/o9dHjJlV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/808602330933424128/o9dHjJlV_normal.jpg',
#     'profile_link_color': '101060',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'PremiosGoya',
#     'statuses_count': 3475,
#     'time_zone': 'Greenland',
#     'translator_type': 'none',
#     'url': 'https://t.co/VOazu7ACyg',
#     'utc_offset': -10800,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @PremiosGoya: Pau Costa y Félix Bergés son los ganadores del #Goya2017 a Mejores Efectos Especiales por Un monstruo viene a verme. ¡Y ya…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Dec 09 14:42:58 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Sonsoles Zatarain. Lda. en Derecho. Opositando Justicia.Labor Omnia Vincit.Igualdad y libertad.\r\nCántabra. Senderismo/ la Mar.\r\nSoy de Azuqueca de Henares',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 2564,
#    'follow_request_sent': False,
#    'followers_count': 687,
#    'following': False,
#    'friends_count': 831,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 999426997,
#    'id_str': '999426997',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 26,
#    'location': '',
#    'name': 'Sonsoles Zatarain',
#    'notifications': False,
#    'profile_background_color': 'DD2E44',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000079200427/4c07597d63a4f9800674143e57ad6879.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000079200427/4c07597d63a4f9800674143e57ad6879.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/999426997/1469705012',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/816674470228332544/qHwdhCfv_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/816674470228332544/qHwdhCfv_normal.jpg',
#    'profile_link_color': 'DD2E44',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'F6FFD1',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'SonsoZatarain',
#    'statuses_count': 5338,
#    'time_zone': 'Amsterdam',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 3600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Feb 05 18:05:07 +0000 2017',
#   'entities': {'hashtags': [{'indices': [16, 25], 'text': 'Goya2017'}],
#    'symbols': [],
#    'urls': [{'display_url': 'rtve.es/noticias/los-g…',
#      'expanded_url': 'http://www.rtve.es/noticias/los-goya/directo/?ext=ggTTR',
#      'indices': [113, 136],
#      'url': 'https://t.co/PLOrygZqR4'}],
#    'user_mentions': [{'id': 57986415,
#      'id_str': '57986415',
#      'indices': [3, 11],
#      'name': 'TVE',
#      'screen_name': 'tve_tve'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 828303454456029184,
#   'id_str': '828303454456029184',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 30,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Feb 04 21:37:27 +0000 2017',
#    'entities': {'hashtags': [{'indices': [3, 12], 'text': 'Goya2017'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/827994501637496833',
#       'indices': [101, 124],
#       'url': 'https://t.co/g5Ma5RvFCR'}],
#     'user_mentions': []},
#    'favorite_count': 76,
#    'favorited': False,
#    'geo': None,
#    'id': 827994501637496833,
#    'id_str': '827994501637496833',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 30,
#    'retweeted': False,
#    'source': '<a href="http://snappytv.com" rel="nofollow">SnappyTV.com</a>',
#    'text': 'El #Goya2017 a la mejor dirección de arte es para Eugenio Caballero por ‘Un monstruo viene a verme’… https://t.co/g5Ma5RvFCR',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Jul 18 17:42:20 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'TVE te informa de toda su actualidad al minuto.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'rtve.es/television',
#         'expanded_url': 'http://www.rtve.es/television',
#         'indices': [0, 22],
#         'url': 'http://t.co/KFb1Bw5rSt'}]}},
#     'favourites_count': 162,
#     'follow_request_sent': False,
#     'followers_count': 494916,
#     'following': False,
#     'friends_count': 110,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 57986415,
#     'id_str': '57986415',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 4793,
#     'location': 'Madrid, España',
#     'name': 'TVE',
#     'notifications': False,
#     'profile_background_color': '0072FF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/280190690/TW_tve.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/280190690/TW_tve.jpg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/57986415/1398329854',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/768466852725030912/f0amQkXU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/768466852725030912/f0amQkXU_normal.jpg',
#     'profile_link_color': '0072FF',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'tve_tve',
#     'statuses_count': 48581,
#     'time_zone': 'Madrid',
#     'translator_type': 'none',
#     'url': 'http://t.co/KFb1Bw5rSt',
#     'utc_offset': 3600,
#     'verified': True}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @tve_tve: El #Goya2017 a la mejor dirección de arte es para Eugenio Caballero por ‘Un monstruo viene a verme’ https://t.co/PLOrygZqR4 ht…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jan 04 14:13:32 +0000 2014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'BELISARIO DOMINGUEZ 625',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 41,
#    'follow_request_sent': False,
#    'followers_count': 207,
#    'following': False,
#    'friends_count': 389,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 2276172698,
#    'id_str': '2276172698',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 44,
#    'location': 'en centro de jalisco Mexico.',
#    'name': 'HOTEL NAVARRO',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2276172698/1483153653',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/826506882533634050/H3chpr7t_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/826506882533634050/H3chpr7t_normal.jpg',
#    'profile_link_color': 'F5ABB5',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'tayloroterocamp',
#    'statuses_count': 15036,
#    'time_zone': 'London',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 0,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Feb 05 18:05:04 +0000 2017',
#   'entities': {'hashtags': [{'indices': [128, 137], 'text': 'goya2017'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1568575706,
#      'id_str': '1568575706',
#      'indices': [3, 17],
#      'name': 'LOSANTOSPOSTS Ⓜ️',
#      'screen_name': 'LosantosPosts'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 828303440543612928,
#   'id_str': '828303440543612928',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 90,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Feb 05 14:49:37 +0000 2017',
#    'entities': {'hashtags': [{'indices': [109, 118], 'text': 'goya2017'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 112,
#    'favorited': False,
#    'geo': None,
#    'id': 828254254594981888,
#    'id_str': '828254254594981888',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 90,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Para ser comunista español, hay que ser muy rico. Una Ana Belén, una Carmena, un Wyoming o un Víctor Manuel.\n#goya2017',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Jul 04 16:38:15 +0000 2013',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '99% REFLEXIONES DE LOSANTOS. Federico no tiene Twitter, pero Twitter sí tiene a Federico. La ficción supera a la realidad CM:Agente Doble(CommentaryAccount)',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 12619,
#     'follow_request_sent': False,
#     'followers_count': 33532,
#     'following': False,
#     'friends_count': 93,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1568575706,
#     'id_str': '1568575706',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 425,
#     'location': 'Imperio Español ',
#     'name': 'LOSANTOSPOSTS Ⓜ️',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1568575706/1478691029',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/726194929240793088/R1bVjoRE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/726194929240793088/R1bVjoRE_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'LosantosPosts',
#     'statuses_count': 25176,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @LosantosPosts: Para ser comunista español, hay que ser muy rico. Una Ana Belén, una Carmena, un Wyoming o un Víctor Manuel.\n#goya2017',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Apr 19 22:33:08 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Pesimista antropológico pero convencido de que, al final, los malos siempre pierden. | #Deporte y #Montaña #Demócrata #Liberal | De #ElBierzo a #Ronda #España',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 3903,
#    'follow_request_sent': False,
#    'followers_count': 1181,
#    'following': False,
#    'friends_count': 559,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 284756189,
#    'id_str': '284756189',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 48,
#    'location': 'Ronda',
#    'name': 'Nardi Crespo Prada',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/595158033/upha0gqjqeykzl7jshpw.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/595158033/upha0gqjqeykzl7jshpw.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/284756189/1479253640',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/797232390716407808/QtLj6QBR_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/797232390716407808/QtLj6QBR_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'D5F4FA',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Nardicrespo',
#    'statuses_count': 19498,
#    'time_zone': 'Madrid',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 3600,
#    'verified': False}}]

# %%
search_results['statuses'][0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Feb 05 18:08:44 +0000 2017',
#  'entities': {'hashtags': [{'indices': [30, 39], 'text': 'Goya2017'}],
#   'media': [{'display_url': 'pic.twitter.com/Zxcl9EAMvJ',
#     'expanded_url': 'https://twitter.com/Aquel_Coche/status/828000811263393793/photo/1',
#     'id': 828000805970182145,
#     'id_str': '828000805970182145',
#     'indices': [40, 63],
#     'media_url': 'http://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#     'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 599},
#      'medium': {'h': 399, 'resize': 'fit', 'w': 599},
#      'small': {'h': 399, 'resize': 'fit', 'w': 599},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'source_status_id': 828000811263393793,
#     'source_status_id_str': '828000811263393793',
#     'source_user_id': 3380960747,
#     'source_user_id_str': '3380960747',
#     'type': 'photo',
#     'url': 'https://t.co/Zxcl9EAMvJ'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 3380960747,
#     'id_str': '3380960747',
#     'indices': [3, 15],
#     'name': 'S_Coche',
#     'screen_name': 'Aquel_Coche'}]},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/Zxcl9EAMvJ',
#     'expanded_url': 'https://twitter.com/Aquel_Coche/status/828000811263393793/photo/1',
#     'id': 828000805970182145,
#     'id_str': '828000805970182145',
#     'indices': [40, 63],
#     'media_url': 'http://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#     'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 599},
#      'medium': {'h': 399, 'resize': 'fit', 'w': 599},
#      'small': {'h': 399, 'resize': 'fit', 'w': 599},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'source_status_id': 828000811263393793,
#     'source_status_id_str': '828000811263393793',
#     'source_user_id': 3380960747,
#     'source_user_id_str': '3380960747',
#     'type': 'photo',
#     'url': 'https://t.co/Zxcl9EAMvJ'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 828304366885076997,
#  'id_str': '828304366885076997',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'es',
#  'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 582,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Feb 04 22:02:31 +0000 2017',
#   'entities': {'hashtags': [{'indices': [13, 22], 'text': 'Goya2017'}],
#    'media': [{'display_url': 'pic.twitter.com/Zxcl9EAMvJ',
#      'expanded_url': 'https://twitter.com/Aquel_Coche/status/828000811263393793/photo/1',
#      'id': 828000805970182145,
#      'id_str': '828000805970182145',
#      'indices': [23, 46],
#      'media_url': 'http://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#      'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 599},
#       'medium': {'h': 399, 'resize': 'fit', 'w': 599},
#       'small': {'h': 399, 'resize': 'fit', 'w': 599},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/Zxcl9EAMvJ'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/Zxcl9EAMvJ',
#      'expanded_url': 'https://twitter.com/Aquel_Coche/status/828000811263393793/photo/1',
#      'id': 828000805970182145,
#      'id_str': '828000805970182145',
#      'indices': [23, 46],
#      'media_url': 'http://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C32mWJmXAAEZy0f.jpg',
#      'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 599},
#       'medium': {'h': 399, 'resize': 'fit', 'w': 599},
#       'small': {'h': 399, 'resize': 'fit', 'w': 599},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/Zxcl9EAMvJ'}]},
#   'favorite_count': 617,
#   'favorited': False,
#   'geo': None,
#   'id': 828000811263393793,
#   'id_str': '828000811263393793',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 582,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'Mejor corto.\n#Goya2017 https://t.co/Zxcl9EAMvJ',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jul 17 22:30:41 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'La mayoría de mis seguidores son taxistas.\n COMPENDIO DE PARIDAS, AQUÍ:\nhttps://t.co/HcsFGrNrEh',
#    'entities': {'description': {'urls': [{'display_url': 'twitter.com/Aquel_Coche/st…',
#        'expanded_url': 'https://twitter.com/Aquel_Coche/status/775401318722797568',
#        'indices': [72, 95],
#        'url': 'https://t.co/HcsFGrNrEh'}]},
#     'url': {'urls': [{'display_url': 'es.favstar.fm/users/Aquel_Co…',
#        'expanded_url': 'http://es.favstar.fm/users/Aquel_Coche',
#        'indices': [0, 23],
#        'url': 'https://t.co/E3fWGijh5l'}]}},
#    'favourites_count': 12219,
#    'follow_request_sent': False,
#    'followers_count': 2730,
#    'following': False,
#    'friends_count': 495,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 3380960747,
#    'id_str': '3380960747',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 42,
#    'location': 'On the road',
#    'name': 'S_Coche',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3380960747/1447257246',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/818937243373109248/ZbTnVVih_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/818937243373109248/ZbTnVVih_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Aquel_Coche',
#    'statuses_count': 16740,
#    'time_zone': 'Lisbon',
#    'translator_type': 'none',
#    'url': 'https://t.co/E3fWGijh5l',
#    'utc_offset': 0,
#    'verified': False}},
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'text': 'RT @Aquel_Coche: Mejor corto.\n#Goya2017 https://t.co/Zxcl9EAMvJ',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Mon Feb 08 17:33:26 +0000 2016',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': '',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 1660,
#   'follow_request_sent': False,
#   'followers_count': 208,
#   'following': False,
#   'friends_count': 915,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 4889145250,
#   'id_str': '4889145250',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'es',
#   'listed_count': 11,
#   'location': '',
#   'name': 'buenprovecho',
#   'notifications': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4889145250/1454953180',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/696749674661867520/qu2HwUKz_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/696749674661867520/qu2HwUKz_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': '_buenprovecho_',
#   'statuses_count': 6787,
#   'time_zone': 'Central America',
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': -21600,
#   'verified': False}}

# %%
search_results['statuses'][0]['user']
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Mon Feb 08 17:33:26 +0000 2016',
#  'default_profile': True,
#  'default_profile_image': False,
#  'description': '',
#  'entities': {'description': {'urls': []}},
#  'favourites_count': 1660,
#  'follow_request_sent': False,
#  'followers_count': 208,
#  'following': False,
#  'friends_count': 915,
#  'geo_enabled': False,
#  'has_extended_profile': False,
#  'id': 4889145250,
#  'id_str': '4889145250',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': 'es',
#  'listed_count': 11,
#  'location': '',
#  'name': 'buenprovecho',
#  'notifications': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4889145250/1454953180',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/696749674661867520/qu2HwUKz_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/696749674661867520/qu2HwUKz_normal.jpg',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': '_buenprovecho_',
#  'statuses_count': 6787,
#  'time_zone': 'Central America',
#  'translator_type': 'none',
#  'url': None,
#  'utc_offset': -21600,
#  'verified': False}

# %% [markdown]
# Vamos a crear nuestros modelos. Primero haremos uno para los tweets, donde podremos utilizar las propiedades que querramos, pero por ejemplo, podriamos usar los siguientes:
# * `created_at`
# * `text`
# * `retweet_count`
# * `favorite_count`
# * `hashtags`
# * `urls`
# * `mentions`
# * `user_id`
#
# Para los usuarios podríamos usar algo así:
# * `created_at`
# * `screen_name`
# * `name`
# * `description`
# * `favourites_count`
# * `followers_count`
# * `friends_count`
# * `profile_image_url`
#
# Algunos de ellos no existen como tal en los resultados de la API, pero para ello podremos programar funciones que nos transformen los resultados en datos válidos para el modelo.

# %%
class Tweet(Document):
    ######################################################
    # Here we need a block for the properties
    ######################################################
    # Set some fields with default and required parameters
    ######################################################
    user_id = ObjectIdField(required=True)
    created_at = DateTimeField(required=True)
    text = StringField()
    retweet_count = IntField(required=True)
    favorite_count = IntField(required=True)
    hashtags = ListField(StringField())
    urls = ListField(URLField())
    mentions = ListField()
    

class User(Document):
    ######################################################
    # Here we need a block for the properties
    ######################################################
    # Set some fields with default and required parameters
    ######################################################
    created_at = DateTimeField(required=True)
    screen_name = StringField(max_length=50, required=True)
    name = StringField()
    description = StringField()
    favourites_count = IntField(required=True)
    followers_count = IntField(required=True)
    friends_count = IntField(required=True)
    profile_image_url = URLField()
    location = StringField()

# %%
# Function for transform the datetime from Twitter to Python's format
def twitter_date_to_datetime(twitter_date):
    return datetime.datetime.strptime(twitter_date, '%a %b %d %H:%M:%S +0000 %Y')

## Constructors for the documents
# User getter and constructor
def get_or_create_user(api_user):
    user = User.objects(screen_name=api_user['screen_name']).first()
    if not user:
        user = User()
        
        user['created_at'] = twitter_date_to_datetime(api_user['created_at'])
        user['screen_name'] = api_user['screen_name']
        ###############################################
        # Here we need a block for link more properties
        ###############################################
        user['name'] = api_user['name']  
        user['description'] = api_user['description']
        user['favourites_count'] = api_user['favourites_count']
        user['followers_count'] = api_user['followers_count']
        user['friends_count'] = api_user['friends_count']
        user['profile_image_url'] = api_user['profile_image_url']
        user['location'] = api_user['location']
        ##################################
        # And now we must persist the user
        ##################################
        user.save()
    
    return user

# Tweet constructor
def create_tweet(api_tweet, user):
    tweet = Tweet()
    
    tweet['created_at'] = twitter_date_to_datetime(api_tweet['created_at'])
    tweet['text'] = api_tweet['text']
    ###############################################
    # Here we need a block for link more properties
    ###############################################

    hashtags = [hashtag['text'] for hashtag in api_tweet['entities']['hashtags']]
    urls = [url['expanded_url'] for url in api_tweet['entities']['urls']]
    mentions = [mention['screen_name'] for mention in api_tweet['entities']['user_mentions']]
    
    tweet['hashtags'] = hashtags
    tweet['urls'] = urls
    tweet['mentions'] = mentions
    ###############################################
    # Here we need a block for link more properties
    ###############################################
    tweet['retweet_count'] = api_tweet['retweet_count']
    tweet['favorite_count'] = api_tweet['favorite_count']
    
    tweet['user_id'] = user.id
    
    ###################################
    # And now we must persist the tweet
    ###################################
    tweet.save()
    
    
    return tweet

# %% [markdown]
# Por último, vamos a rellenar nuestra base de datos con los resultados obtenidos y comprobar en RoboMongo los resultados.

# %%
for result in search_results['statuses']:
    api_user = result['user']
    user = get_or_create_user(api_user)
    tweet = create_tweet(result, user)
